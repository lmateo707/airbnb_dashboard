# %%
# dependencies and setup
import pandas as pd
from sqlalchemy import create_engine

# %%
# Store CSV to DataFrame
listings_file = "resources/listings.csv"
listing_host_df = pd.read_csv(listings_file)

# %%
# change column "name" to something that SQL doesn't already recognize
listing_host_df.rename(index=str,columns={"name":"listing_name"},inplace=True)
# listing_host_df.head()
print(listings_host_df.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'access', 'interaction', 'house_rules',
#        'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'license', 'jurisdiction_names', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ## Create "Listings" dataframe and clean it

# %%
# Create new data with select columns for the AirBnB listings
listing_df = listing_host_df[["id","listing_name","street","neighbourhood_cleansed",
                              "zipcode","latitude","longitude","property_type","room_type",
                              "accommodates","bathrooms","bedrooms","beds","bed_type","price",
                              "weekly_price","monthly_price","security_deposit","cleaning_fee",
                              "guests_included","extra_people","has_availability","availability_30",
                              "availability_60","availability_90","availability_365","number_of_reviews",
                              "review_scores_rating","review_scores_accuracy","review_scores_cleanliness",
                              "review_scores_checkin","review_scores_communication","review_scores_location",
                              "review_scores_value","requires_license","instant_bookable",
                              "cancellation_policy","host_id"]].copy()

# %%
# convert boolean columns to boolean
# listing_df["has_availability"].replace(["t","f"],[True,False],inplace=True)
listing_df["requires_license"].replace(["t","f"],[True,False],inplace=True)
listing_df["instant_bookable"].replace(["t","f"],[True,False],inplace=True)

# %%
# convert all the currency columns to numeric values instead of strings
# define the currency columns
currency_cols=["price","weekly_price","monthly_price","security_deposit","cleaning_fee","extra_people"]
# remove dollar sign and commas
listing_df[currency_cols]=listing_df[currency_cols].replace({'\$': '', ',': ''}, regex=True)
# changing the leftover value (minus currency sign and commas) to a number
listing_df["price"] = pd.to_numeric(listing_df["price"])
listing_df["weekly_price"] = pd.to_numeric(listing_df["weekly_price"])
listing_df["monthly_price"] = pd.to_numeric(listing_df["monthly_price"])
listing_df["security_deposit"] = pd.to_numeric(listing_df["security_deposit"])
listing_df["cleaning_fee"] = pd.to_numeric(listing_df["cleaning_fee"])
listing_df["extra_people"] = pd.to_numeric(listing_df["extra_people"])
listing_df.head()
# Out:
#          id                                   listing_name  \
# 0  12147973                     Sunny Bungalow in the City
# 1   3075044              Charming room in pet friendly apt
# 2      6976               Mexican Folk Art Haven in Boston
# 3   1436513  Spacious Sunny Bedroom Suite in Historic Home
# 4   7651065                            Come Home to Boston
#
#                                               street neighbourhood_cleansed  \
# 0      Birch Street, Boston, MA 02131, United States             Roslindale
# 1  Pinehurst Street, Boston, MA 02131, United States             Roslindale
# 2        Ardale St., Boston, MA 02131, United States             Roslindale
# 3                          Boston, MA, United States             Roslindale
# 4    Durnell Avenue, Boston, MA 02131, United States             Roslindale
#
#   zipcode   latitude  longitude property_type        room_type  accommodates  \
# 0   02131  42.282619 -71.133068         House  Entire home/apt             4
# 1   02131  42.286241 -71.134374     Apartment     Private room             2
# 2   02131  42.292438 -71.135765     Apartment     Private room             2
# 3     NaN  42.281106 -71.121021         House     Private room             4
# 4   02131  42.284512 -71.136258         House     Private room             2
#
#    ...  review_scores_accuracy  review_scores_cleanliness  \
# 0  ...                     NaN                        NaN
# 1  ...                    10.0                        9.0
# 2  ...                    10.0                        9.0
# 3  ...                    10.0                       10.0
# 4  ...                    10.0                       10.0
#
#    review_scores_checkin review_scores_communication  review_scores_location  \
# 0                    NaN                         NaN                     NaN
# 1                   10.0                        10.0                     9.0
# 2                   10.0                        10.0                     9.0
# 3                   10.0                        10.0                    10.0
# 4                   10.0                        10.0                     9.0
#
#    review_scores_value  requires_license  instant_bookable  \
# 0                  NaN             False             False
# 1                  9.0             False              True
# 2                 10.0             False             False
# 3                 10.0             False             False
# 4                 10.0             False             False
#
#    cancellation_policy   host_id
# 0             moderate  31303940
# 1             moderate   2572247
# 2             moderate     16701
# 3             moderate   6031442
# 4             flexible  15396970
#
# [5 rows x 38 columns]

# %%
print(listing_df.columns)
# Out:
# Index(['id', 'listing_name', 'street', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'cancellation_policy', 'host_id'],
#       dtype='object')

# %% [markdown]
# ## Create "Hosts" dataframe and clean it

# %%
# Create new data with select columns for the AirBnB hosts
host_df = listing_host_df[["host_id","host_name","host_since","host_location","host_response_time",
                           "host_response_rate","host_acceptance_rate","host_is_superhost",
                           "host_neighbourhood","host_listings_count","host_has_profile_pic",
                           "host_identity_verified"]].copy()

# %%
# delete duplicates
host_df.drop_duplicates(keep="first",inplace=True)

# %%
# convert dates to datetime format
host_df["host_since"]=pd.to_datetime(host_df["host_since"])

# %%
# convert boolean columns to boolean
host_df["host_is_superhost"].replace(["t","f"],[True,False],inplace=True)
host_df["host_has_profile_pic"].replace(["t","f"],[True,False],inplace=True)
host_df["host_identity_verified"].replace(["t","f"],[True,False],inplace=True)

# %%
# converting the percentage columns from strings to percentages
# remove the percentage symbols from the columns with percentages
host_df["host_response_rate"]=host_df["host_response_rate"].replace({'\$': '', ',': '', '%':''}, regex=True)
host_df["host_acceptance_rate"]=host_df["host_acceptance_rate"].replace({'\$': '', ',': '', '%':''}, regex=True)
# convert the percentage columns to numbers
host_df["host_response_rate"] = pd.to_numeric(host_df["host_response_rate"])
host_df["host_acceptance_rate"] = pd.to_numeric(host_df["host_acceptance_rate"])
host_df.head()
# Out:
#     host_id host_name host_since                         host_location  \
# 0  31303940  Virginia 2015-04-15  Boston, Massachusetts, United States
# 1   2572247    Andrea 2012-06-07  Boston, Massachusetts, United States
# 2     16701      Phil 2009-05-11  Boston, Massachusetts, United States
# 3   6031442    Meghna 2013-04-21  Boston, Massachusetts, United States
# 4  15396970     Linda 2014-05-11  Boston, Massachusetts, United States
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 0                 NaN                 NaN                   NaN
# 1      within an hour               100.0                 100.0
# 2  within a few hours               100.0                  88.0
# 3  within a few hours               100.0                  50.0
# 4      within an hour               100.0                 100.0
#
#    host_is_superhost host_neighbourhood  host_listings_count  \
# 0              False         Roslindale                    1
# 1              False         Roslindale                    1
# 2               True         Roslindale                    1
# 3              False                NaN                    1
# 4               True         Roslindale                    1
#
#    host_has_profile_pic  host_identity_verified
# 0                  True                   False
# 1                  True                    True
# 2                  True                    True
# 3                  True                   False
# 4                  True                    True

# %%
print(host_df.columns)
# Out:
# Index(['host_id', 'host_name', 'host_since', 'host_location',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
#        'host_has_profile_pic', 'host_identity_verified'],
#       dtype='object')

# %% [markdown]
# ## Create the "Reviews" dataframe and clean it

# %%
# Store CSV to DataFrame
reviews_file = "resources/reviews.csv"
reviews_df = pd.read_csv(reviews_file)
reviews_df.head()
# Out:
#    listing_id       id        date  reviewer_id reviewer_name  \
# 0     1178162  4724140  2013-05-21      4298113       Olivier
# 1     1178162  4869189  2013-05-29      6452964     Charlotte
# 2     1178162  5003196  2013-06-06      6449554     Sebastian
# 3     1178162  5150351  2013-06-15      2215611        Marine
# 4     1178162  5171140  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %%
# change column "date/id" to something that SQL doesn't already recognize
reviews_df.rename(index=str,columns={"date":"review_date"},inplace=True)
reviews_df.rename(columns={"id":"review_id"}, inplace=True)

# %%
# Create new data with select columns for the AirBnB listings
review_df = reviews_df[['review_id', "listing_id", "review_date", "reviewer_id", "reviewer_name", "comments"]].copy()

# %%
# convert dates to datetime
review_df["review_date"] = pd.to_datetime(review_df["review_date"])
review_df.head()
# Out:
#    review_id  listing_id review_date  reviewer_id reviewer_name  \
# 0    4724140     1178162  2013-05-21      4298113       Olivier
# 1    4869189     1178162  2013-05-29      6452964     Charlotte
# 2    5003196     1178162  2013-06-06      6449554     Sebastian
# 3    5150351     1178162  2013-06-15      2215611        Marine
# 4    5171140     1178162  2013-06-16      6848427        Andrew
#
#                                             comments
# 0  My stay at islam's place was really cool! Good...
# 1  Great location for both airport and city - gre...
# 2  We really enjoyed our stay at Islams house. Fr...
# 3  The room was nice and clean and so were the co...
# 4  Great location. Just 5 mins walk from the Airp...

# %% [markdown]
# ## Remove Neighborhoods that we're not using and clean relevant columns

# %%
listing_df.head()
# Out:
#          id                                   listing_name  \
# 0  12147973                     Sunny Bungalow in the City
# 1   3075044              Charming room in pet friendly apt
# 2      6976               Mexican Folk Art Haven in Boston
# 3   1436513  Spacious Sunny Bedroom Suite in Historic Home
# 4   7651065                            Come Home to Boston
#
#                                               street neighbourhood_cleansed  \
# 0      Birch Street, Boston, MA 02131, United States             Roslindale
# 1  Pinehurst Street, Boston, MA 02131, United States             Roslindale
# 2        Ardale St., Boston, MA 02131, United States             Roslindale
# 3                          Boston, MA, United States             Roslindale
# 4    Durnell Avenue, Boston, MA 02131, United States             Roslindale
#
#   zipcode   latitude  longitude property_type        room_type  accommodates  \
# 0   02131  42.282619 -71.133068         House  Entire home/apt             4
# 1   02131  42.286241 -71.134374     Apartment     Private room             2
# 2   02131  42.292438 -71.135765     Apartment     Private room             2
# 3     NaN  42.281106 -71.121021         House     Private room             4
# 4   02131  42.284512 -71.136258         House     Private room             2
#
#    ...  review_scores_accuracy  review_scores_cleanliness  \
# 0  ...                     NaN                        NaN
# 1  ...                    10.0                        9.0
# 2  ...                    10.0                        9.0
# 3  ...                    10.0                       10.0
# 4  ...                    10.0                       10.0
#
#    review_scores_checkin review_scores_communication  review_scores_location  \
# 0                    NaN                         NaN                     NaN
# 1                   10.0                        10.0                     9.0
# 2                   10.0                        10.0                     9.0
# 3                   10.0                        10.0                    10.0
# 4                   10.0                        10.0                     9.0
#
#    review_scores_value  requires_license  instant_bookable  \
# 0                  NaN             False             False
# 1                  9.0             False              True
# 2                 10.0             False             False
# 3                 10.0             False             False
# 4                 10.0             False             False
#
#    cancellation_policy   host_id
# 0             moderate  31303940
# 1             moderate   2572247
# 2             moderate     16701
# 3             moderate   6031442
# 4             flexible  15396970
#
# [5 rows x 38 columns]

# %%
listing_df.groupby("neighbourhood_cleansed").count()
# Out:
#                           id  listing_name  street  zipcode  latitude  \
# neighbourhood_cleansed
# Allston                  260           260     260      258       260
# Back Bay                 302           302     302      299       302
# Bay Village               24            24      24       24        24
# Beacon Hill              194           194     194      194       194
# Brighton                 185           185     185      183       185
# Charlestown              111           111     111      111       111
# Chinatown                 71            71      71       71        71
# Dorchester               269           269     269      265       269
# Downtown                 172           172     172      170       172
# East Boston              150           150     150      146       150
# Fenway                   290           290     290      287       290
# Hyde Park                 31            31      31       31        31
# Jamaica Plain            343           343     343      340       343
# Leather District           5             5       5        5         5
# Longwood Medical Area      9             9       9        7         9
# Mattapan                  24            24      24       24        24
# Mission Hill             124           124     124      123       124
# North End                143           143     143      140       143
# Roslindale                56            56      56       55        56
# Roxbury                  144           144     144      143       144
# South Boston             174           174     174      173       174
# South Boston Waterfront   83            83      83       81        83
# South End                326           326     326      322       326
# West End                  49            49      49       49        49
# West Roxbury              46            46      46       46        46
#
#                          longitude  property_type  room_type  accommodates  \
# neighbourhood_cleansed
# Allston                        260            259        260           260
# Back Bay                       302            301        302           302
# Bay Village                     24             24         24            24
# Beacon Hill                    194            194        194           194
# Brighton                       185            185        185           185
# Charlestown                    111            111        111           111
# Chinatown                       71             71         71            71
# Dorchester                     269            269        269           269
# Downtown                       172            171        172           172
# East Boston                    150            150        150           150
# Fenway                         290            290        290           290
# Hyde Park                       31             31         31            31
# Jamaica Plain                  343            343        343           343
# Leather District                 5              5          5             5
# Longwood Medical Area            9              9          9             9
# Mattapan                        24             24         24            24
# Mission Hill                   124            124        124           124
# North End                      143            143        143           143
# Roslindale                      56             56         56            56
# Roxbury                        144            144        144           144
# South Boston                   174            174        174           174
# South Boston Waterfront         83             83         83            83
# South End                      326            326        326           326
# West End                        49             49         49            49
# West Roxbury                    46             46         46            46
#
#                          bathrooms  ...  review_scores_accuracy  \
# neighbourhood_cleansed              ...
# Allston                        260  ...                     181
# Back Bay                       302  ...                     236
# Bay Village                     24  ...                      16
# Beacon Hill                    194  ...                     168
# Brighton                       185  ...                     133
# Charlestown                    111  ...                      76
# Chinatown                       71  ...                      41
# Dorchester                     267  ...                     223
# Downtown                       172  ...                     118
# East Boston                    150  ...                     136
# Fenway                         288  ...                     185
# Hyde Park                       31  ...                      25
# Jamaica Plain                  342  ...                     293
# Leather District                 5  ...                       3
# Longwood Medical Area            9  ...                       3
# Mattapan                        24  ...                      18
# Mission Hill                   124  ...                      81
# North End                      141  ...                     120
# Roslindale                      56  ...                      50
# Roxbury                        139  ...                     116
# South Boston                   174  ...                     153
# South Boston Waterfront         83  ...                      58
# South End                      324  ...                     269
# West End                        49  ...                      27
# West Roxbury                    46  ...                      33
#
#                          review_scores_cleanliness  review_scores_checkin  \
# neighbourhood_cleansed
# Allston                                        182                    182
# Back Bay                                       236                    236
# Bay Village                                     16                     16
# Beacon Hill                                    168                    168
# Brighton                                       133                    133
# Charlestown                                     76                     76
# Chinatown                                       41                     41
# Dorchester                                     223                    223
# Downtown                                       118                    118
# East Boston                                    136                    136
# Fenway                                         185                    185
# Hyde Park                                       25                     25
# Jamaica Plain                                  295                    295
# Leather District                                 3                      3
# Longwood Medical Area                            3                      3
# Mattapan                                        18                     18
# Mission Hill                                    82                     81
# North End                                      120                    120
# Roslindale                                      50                     50
# Roxbury                                        117                    116
# South Boston                                   153                    153
# South Boston Waterfront                         58                     58
# South End                                      269                    269
# West End                                        27                     27
# West Roxbury                                    33                     33
#
#                          review_scores_communication  review_scores_location  \
# neighbourhood_cleansed
# Allston                                          182                     181
# Back Bay                                         236                     236
# Bay Village                                       16                      16
# Beacon Hill                                      168                     168
# Brighton                                         133                     133
# Charlestown                                       76                      76
# Chinatown                                         41                      41
# Dorchester                                       224                     224
# Downtown                                         118                     118
# East Boston                                      136                     136
# Fenway                                           185                     185
# Hyde Park                                         25                      25
# Jamaica Plain                                    294                     295
# Leather District                                   3                       3
# Longwood Medical Area                              3                       3
# Mattapan                                          18                      18
# Mission Hill                                      82                      80
# North End                                        120                     120
# Roslindale                                        50                      50
# Roxbury                                          117                     116
# South Boston                                     153                     153
# South Boston Waterfront                           58                      58
# South End                                        269                     268
# West End                                          27                      27
# West Roxbury                                      33                      33
#
#                          review_scores_value  requires_license  \
# neighbourhood_cleansed
# Allston                                  182               260
# Back Bay                                 235               302
# Bay Village                               16                24
# Beacon Hill                              168               194
# Brighton                                 133               185
# Charlestown                               76               111
# Chinatown                                 41                71
# Dorchester                               224               269
# Downtown                                 118               172
# East Boston                              136               150
# Fenway                                   185               290
# Hyde Park                                 25                31
# Jamaica Plain                            295               343
# Leather District                           3                 5
# Longwood Medical Area                      3                 9
# Mattapan                                  18                24
# Mission Hill                              80               124
# North End                                120               143
# Roslindale                                50                56
# Roxbury                                  116               144
# South Boston                             153               174
# South Boston Waterfront                   58                83
# South End                                269               326
# West End                                  27                49
# West Roxbury                              33                46
#
#                          instant_bookable  cancellation_policy  host_id
# neighbourhood_cleansed
# Allston                               260                  260      260
# Back Bay                              302                  302      302
# Bay Village                            24                   24       24
# Beacon Hill                           194                  194      194
# Brighton                              185                  185      185
# Charlestown                           111                  111      111
# Chinatown                              71                   71       71
# Dorchester                            269                  269      269
# Downtown                              172                  172      172
# East Boston                           150                  150      150
# Fenway                                290                  290      290
# Hyde Park                              31                   31       31
# Jamaica Plain                         343                  343      343
# Leather District                        5                    5        5
# Longwood Medical Area                   9                    9        9
# Mattapan                               24                   24       24
# Mission Hill                          124                  124      124
# North End                             143                  143      143
# Roslindale                             56                   56       56
# Roxbury                               144                  144      144
# South Boston                          174                  174      174
# South Boston Waterfront                83                   83       83
# South End                             326                  326      326
# West End                               49                   49       49
# West Roxbury                           46                   46       46
#
# [25 rows x 37 columns]

# %%
# Restrict analysis to only neighborhoods of interest
listing_df = listing_df[listing_df["neighbourhood_cleansed"].isin(["Allston", "Fenway", 
                                                                         "Downtown", "Jamaica Plain"])]

# %%
# Remove rows that have 0 values for relevant columns
listing_df = listing_df[listing_df["price"] != 0]
listing_df = listing_df[listing_df["cancellation_policy"] != 0]
listing_df = listing_df[listing_df["room_type"] != 0]
listing_df = listing_df[listing_df["review_scores_value"] != 0]
listing_df = listing_df[listing_df["number_of_reviews"] != 0]

# Remove rows that have N/A for relevant columns
listing_df.dropna(subset=["price","cancellation_policy","room_type",
                          "review_scores_value","number_of_reviews","bedrooms","bathrooms"],how="any",inplace=True)

# %%
# Reduce the host dataframe to only the relevant neighborhoods
host_reduced_df = pd.merge(listing_df,host_df,how="left",left_on=["host_id"],right_on=["host_id"])
host_reduced_df.dropna(subset=["price","cancellation_policy","room_type",
                               "review_scores_value","number_of_reviews"],how="any",inplace=True)

host_reduced_df = host_reduced_df[["host_id","host_name","host_since","host_location","host_response_time","host_response_rate",
                                   "host_acceptance_rate","host_is_superhost","host_neighbourhood","host_listings_count","host_has_profile_pic",
                                   "host_identity_verified"]]

host_reduced_df.drop_duplicates(keep="first",inplace=True)

# %%
# Reduce the reviews dataframe to only the relevant neighborhoods
reviews_reduced_df = pd.merge(reviews_df,listing_df,how="left",left_on=["listing_id"],right_on=["id"])

reviews_reduced_df.dropna(subset=["price","cancellation_policy","room_type","review_scores_value",
                                  "number_of_reviews"],how="any",inplace=True)

reviews_reduced_df = reviews_reduced_df[['review_id', "listing_id", "review_date", "reviewer_id", 
                                         "reviewer_name", "comments"]]


reviews_reduced_df.drop_duplicates(keep="first",inplace=True)

# %% [markdown]
# ## SQL

# %%
#create database connection
connection = "postgres:postgres@localhost:5432/airbnb_db"
engine = create_engine(f'postgresql://{connection}')

# %%
# check tablenames in the MySQL database
engine.table_names()
# Out:
# ['airbnb_hosts', 'listings', 'property_reviews', 'reviews']

# %%
# add the hosts dataframe to MySQL
host_reduced_df.to_sql(name="airbnb_hosts",con=engine,if_exists="append",index=False,chunksize=2000)

# %%
# add the listings dataframe to MySQL
listing_df.to_sql(name="listings",con=engine,if_exists="append",index=False,chunksize=200)

# %%
# add the property reviews dataframe to MySQL
reviews_reduced_df.to_sql(name="property_reviews",con=engine,if_exists="append",index=False,chunksize=2000)

# %%
host_reduced_df.to_csv("./resources/reduced_host.csv",index=False)

# %%
listing_df.to_csv("./resources/cleaned_listing.csv",index=False)

# %%
reviews_reduced_df.to_csv("./resources/cleaned_review.csv",index=False)

# %% [markdown]
# ###Sanity Check

# %%
pd.read_sql_query('select * from listings', con=engine).head()
# Out:
#         id                         listing_name  \
# 0   594693       Private room in peaceful space
# 1  2384581               Loft bedroom, sleeps 2
# 2   735970  Part of a Large Condo Jamaica Plain
# 3  4262255           Beautiful and sunny condo
# 4  4000384        Sunlit room with private bath
#
#                                              street  \
# 0         South St, Boston, MA 02130, United States
# 1  Holbrook Street, Boston, MA 02130, United States
# 2      Beaufort Rd, Boston, MA 02130, United States
# 3    Rossmore Road, Boston, MA 02130, United States
# 4    Copley Street, Boston, MA 02119, United States
#
#   neighbourhood_group_cleansed zipcode   latitude  longitude  \
# 0                         None   02130  42.307975 -71.116221
# 1                         None   02130  42.309357 -71.116827
# 2                         None   02130  42.316912 -71.113025
# 3                         None   02130  42.303985 -71.104494
# 4                         None   02119  42.316329 -71.099096
#
#   is_location_exact    property_type     room_type  ...  \
# 0              None        Apartment  Private room  ...
# 1              None            House  Private room  ...
# 2              None  Bed & Breakfast  Private room  ...
# 3              None        Apartment  Private room  ...
# 4              None            House  Private room  ...
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                          8                     10
# 1                          9                     10
# 2                          9                      9
# 3                         10                     10
# 4                         10                     10
#
#    review_scores_communication  review_scores_location review_scores_value  \
# 0                         10.0                    10.0                   9
# 1                         10.0                    10.0                   9
# 2                          9.0                    10.0                  10
# 3                         10.0                    10.0                  10
# 4                         10.0                     9.0                  10
#
#    requires_license  instant_bookable  cancellation_policy   host_id  \
# 0             False             False               strict   2139546
# 1             False             False             flexible  12083797
# 2             False             False             flexible   3840038
# 3             False             False             moderate  21873698
# 4             False             False             flexible  10910804
#
#    neighbourhood_cleansed
# 0           Jamaica Plain
# 1           Jamaica Plain
# 2           Jamaica Plain
# 3           Jamaica Plain
# 4           Jamaica Plain
#
# [5 rows x 40 columns]

# %%
pd.read_sql_query('select * from airbnb_hosts', con=engine).head()
# Out:
#     host_id  host_name  host_since                         host_location  \
# 0   2139546      Robin  2012-04-14  Boston, Massachusetts, United States
# 1  12083797      Molly  2014-02-09  Boston, Massachusetts, United States
# 2   3840038     Sidney  2012-10-11  Boston, Massachusetts, United States
# 3  21873698  Elizabeth  2014-09-28  Boston, Massachusetts, United States
# 4  10910804     Evelyn  2013-12-30  Boston, Massachusetts, United States
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 0      within an hour               100.0                 100.0
# 1        within a day                93.0                  73.0
# 2                None                 NaN                   NaN
# 3  within a few hours               100.0                  89.0
# 4        within a day                70.0                  85.0
#
#    host_is_superhost host_neighbourhood  host_listings_count  \
# 0              False      Jamaica Plain                    2
# 1              False      Jamaica Plain                    2
# 2              False      Jamaica Plain                    1
# 3               True      Jamaica Plain                    1
# 4              False      Jamaica Plain                    2
#
#    host_has_profile_pic  host_identity_verified
# 0                  True                   False
# 1                  True                    True
# 2                  True                   False
# 3                  True                    True
# 4                  True                    True

# %%
pd.read_sql_query('select * from property_reviews', con=engine).head()
# Out:
#    review_id  listing_id review_date  reviewer_id reviewer_name  \
# 0   57999038     9364092  2015-12-31      1211289          Hani
# 1   58979667     9364092  2016-01-05     51948821         Julia
# 2   62651888     9364092  2016-02-15     47402064       Kathryn
# 3   70617954     9364092  2016-04-19     37224180         André
# 4   92507365     9364092  2016-08-08     26023372         Cheri
#
#                                             comments
# 0  The host canceled this reservation 13 days bef...
# 1  Sergio has a lovely and artistic home. The amb...
# 2  Sergio was a fantastic host.  He is warm, frie...
# 3  Sergio is a fantastic host ! \r\nWe had a grea...
# 4  Sergio was a fantastic host. Our flight was de...
